# %% [markdown]
# # Population Density Data
# Data is unfortunately from the 2010 US Census, and appears to be the most recent available from the census
#
# The following links are relavant:
#  https://www.census.gov/data/tables/2010/dec/density-data-text.html
# * https://www.census.gov/2010census/data/apportionment-data-map.html
#
# Data for this analysis found here:
# * https://www2.census.gov/programs-surveys/decennial/tables/2010/2010-apportionment/pop_density.csv

# %%
import pandas as pd

# %%
url="https://www2.census.gov/programs-surveys/decennial/tables/2010/2010-apportionment/pop_density.csv"
data = pd.read_csv(url)

# %%
data.tail(15)
# Out:
#    # POPULATION DENSITY DATA PROVIDED BY U.S. CENSUS. Unnamed: 1 Unnamed: 2  \
# 41                                             Oregon     672765     783389
# 42                                       Pennsylvania    7665111    8720017
# 43                                       Rhode Island     542610     604397
# 44                                     South Carolina    1515400    1683724
# 45                                       South Dakota     583888     636547
# 46                                          Tennessee    2184789    2337885
# 47                                              Texas    3896542    4663228
# 48                                               Utah     373351     449396
# 49                                            Vermont     355956     352428
# 50                                           Virginia    2061612    2309187
# 51                                         Washington    1141990    1356621
# ...
